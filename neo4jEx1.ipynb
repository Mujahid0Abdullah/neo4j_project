# %%
import pandas as pd
from neo4j import GraphDatabase
host = 'bolt://localhost:7687'
user = 'neo4j'
password = '123123123'
driver = GraphDatabase.driver(host,auth=(user, password))

def run_query(query):
    with driver.session() as session:
        result = session.run(query)
        return pd.DataFrame([r.values() for r in result], columns=result.keys())

# %%
for i in range(18):
    run_query(f"""Create (:Person {{id:{i}, name:'mad'}})""")

# %%
# Out:
#              n
# 0   (name, id)
# 1   (name, id)
# 2   (name, id)
# 3   (name, id)
# 4   (name, id)
# 5   (name, id)
# 6   (name, id)
# 7   (name, id)
# 8   (name, id)
# 9   (name, id)
# 10  (name, id)
# 11  (name, id)
# 12  (name, id)
# 13  (name, id)
# 14  (name, id)
# 15  (name, id)
# 16  (name, id)
# 17  (name, id)
# 18  (name, id)

# %%
import pandas as pd

# %%
df_battle = pd.read_json("C:/Users/Acer/.Neo4jDesktop/relate-data/dbmss/dbms-66f1e2f7-be36-4f2a-99f8-c7bc33af8512/import/battle.json")

# %%
df_battle
# Out:
#       kId          Gazve Adı                 Tarih                     Amaç  \
# 0   27001  Waddan (al-Abwa’)            August 623  Yol keşfi ve ittifaklar
# 1   27002              Buwat         September 623           Kervan baskını
# 2   27003             Safwan         September 623            Düşman takibi
# 3   27004    Zul Al-Ushairah          December 623           Kervan baskını
# 4   27005        Nakhla Raid           January 624           Kervan baskını
# 5   27006               Badr          13 March 624   Kervan baskını / Savaş
# 6   27007       Banu Qaynuqa             April 624           İttifak ihlali
# 7   27008              Sawiq          May/June 624            Düşman takibi
# 8   27009               Uhud          23 March 625                  Savunma
# 9   27010      Hamra al-Asad             March 625            Düşman takibi
# 10  27011         Banu Nadir            August 625           İttifak ihlali
# 11  27012     Badr al-Maw’id             April 626            Düşman takibi
# 12  27013       Dhat al-Riqa              June 626            Düşman takibi
# 13  27014    Dumat al-Jandal  August/September 626           Siyasi kontrol
# 14  27015             Trench             April 627                  Savunma
# 15  27016       Banu Qurayza               May 627           İttifak ihlali
# 16  27017        Banu Lahyan              July 627                  İntikam
# 17  27018          Dhu Qarad            August 627            Düşman takibi
# 18  27019             Mu’tah         September 629           Bizans’a karşı
# 19  27020  Conquest of Mecca           January 630          Mekke’nin fethi
# 20  27021             Hunayn              June 630         Kabilelere karşı
# 21  27022        Ta’if Siege              June 630     Ta’if’in kuşatılması
# 22  27023              Tabuk           October 630           Bizans’a karşı
#
#                 Sonuç              Yer                   Savunanlar  \
# 0        Savaş olmadı         Al-Abwa’                            -
# 1        Savaş olmadı            Buwat                            -
# 2        Savaş olmadı           Safwan                            -
# 3        Savaş olmadı  Zul Al-Ushairah                            -
# 4            Başarılı           Nakhla                  Müslümanlar
# 5         Büyük zafer             Badr                  Müslümanlar
# 6              Sürgün           Medine                  Müslümanlar
# 7        Savaş olmadı                -                            -
# 8               Kayıp             Uhud                  Müslümanlar
# 9        Savaş olmadı    Hamra al-Asad                            -
# 10             Sürgün           Medine                  Müslümanlar
# 11       Savaş olmadı             Badr                            -
# 12       Savaş olmadı     Dhat al-Riqa                            -
# 13           Başarılı  Dumat al-Jandal                            -
# 14           Başarılı           Medine                  Müslümanlar
# 15  Kuşatma ve sürgün           Medine                  Müslümanlar
# 16       Savaş olmadı                -                  Müslümanlar
# 17       Savaş olmadı        Dhu Qarad                            -
# 18              Kayıp           Mu’tah       Bizans ve müttefikleri
# 19           Başarılı            Mekke                       Kureyş
# 20           Başarılı           Hunayn  Ta’if ve Hawazin kabileleri
# 21  Kuşatma başarısız            Ta’if             Ta’if kabileleri
# 22       Savaş olmadı            Tabuk       Bizans ve müttefikleri
#
#            Saldıranlar
# 0          Müslümanlar
# 1          Müslümanlar
# 2          Müslümanlar
# 3          Müslümanlar
# 4               Kureyş
# 5               Kureyş
# 6         Banu Qaynuqa
# 7          Müslümanlar
# 8               Kureyş
# 9          Müslümanlar
# 10          Banu Nadir
# 11         Müslümanlar
# 12         Müslümanlar
# 13         Müslümanlar
# 14  Müttefik kuvvetler
# 15        Banu Qurayza
# 16         Banu Lahyan
# 17         Müslümanlar
# 18         Müslümanlar
# 19         Müslümanlar
# 20         Müslümanlar
# 21         Müslümanlar
# 22         Müslümanlar

# %%
yeni_tarihler= [
    "August 623 (1 AH)",
    "September 623 (1 AH)",
    "September 623 (1 AH)",
    "December 623 (1 AH)",
    "January 624 (2 AH)",
    "13 March 624 (2 AH)",
    "April 624 (2 AH)",
    "May/June 624 (2 AH)",
    "23 March 625 (3 AH)",
    "March 625 (3 AH)",
    "August 625 (3 AH)",
    "April 626 (4 AH)",
    "June 626 (4 AH)",
    "August/September 626 (4 AH)",
    "April 627 (5 AH)",
    "May 627 (5 AH)",
    "July 627 (5 AH)",
    "August 627 (5 AH)",
    "September 629 (7 AH)",
    "January 630 (7 AH)",
    "June 630 (8 AH)",
    "June 630 (8 AH)",
    "October 630 (8 AH)"
]

for i in range(len(df_battle)):
  df_battle.loc[i, "Tarih"] = yeni_tarihler[i]

# %%
df_battle
# Out:
#       kId          Gazve Adı                        Tarih  \
# 0   27001  Waddan (al-Abwa’)            August 623 (1 AH)
# 1   27002              Buwat         September 623 (1 AH)
# 2   27003             Safwan         September 623 (1 AH)
# 3   27004    Zul Al-Ushairah          December 623 (1 AH)
# 4   27005        Nakhla Raid           January 624 (2 AH)
# 5   27006               Badr          13 March 624 (2 AH)
# 6   27007       Banu Qaynuqa             April 624 (2 AH)
# 7   27008              Sawiq          May/June 624 (2 AH)
# 8   27009               Uhud          23 March 625 (3 AH)
# 9   27010      Hamra al-Asad             March 625 (3 AH)
# 10  27011         Banu Nadir            August 625 (3 AH)
# 11  27012     Badr al-Maw’id             April 626 (4 AH)
# 12  27013       Dhat al-Riqa              June 626 (4 AH)
# 13  27014    Dumat al-Jandal  August/September 626 (4 AH)
# 14  27015             Trench             April 627 (5 AH)
# 15  27016       Banu Qurayza               May 627 (5 AH)
# 16  27017        Banu Lahyan              July 627 (5 AH)
# 17  27018          Dhu Qarad            August 627 (5 AH)
# 18  27019             Mu’tah         September 629 (7 AH)
# 19  27020  Conquest of Mecca           January 630 (7 AH)
# 20  27021             Hunayn              June 630 (8 AH)
# 21  27022        Ta’if Siege              June 630 (8 AH)
# 22  27023              Tabuk           October 630 (8 AH)
#
#                        Amaç              Sonuç              Yer  \
# 0   Yol keşfi ve ittifaklar       Savaş olmadı         Al-Abwa’
# 1            Kervan baskını       Savaş olmadı            Buwat
# 2             Düşman takibi       Savaş olmadı           Safwan
# 3            Kervan baskını       Savaş olmadı  Zul Al-Ushairah
# 4            Kervan baskını           Başarılı           Nakhla
# 5    Kervan baskını / Savaş        Büyük zafer             Badr
# 6            İttifak ihlali             Sürgün           Medine
# 7             Düşman takibi       Savaş olmadı                -
# 8                   Savunma              Kayıp             Uhud
# 9             Düşman takibi       Savaş olmadı    Hamra al-Asad
# 10           İttifak ihlali             Sürgün           Medine
# 11            Düşman takibi       Savaş olmadı             Badr
# 12            Düşman takibi       Savaş olmadı     Dhat al-Riqa
# 13           Siyasi kontrol           Başarılı  Dumat al-Jandal
# 14                  Savunma           Başarılı           Medine
# 15           İttifak ihlali  Kuşatma ve sürgün           Medine
# 16                  İntikam       Savaş olmadı                -
# 17            Düşman takibi       Savaş olmadı        Dhu Qarad
# 18           Bizans’a karşı              Kayıp           Mu’tah
# 19          Mekke’nin fethi           Başarılı            Mekke
# 20         Kabilelere karşı           Başarılı           Hunayn
# 21     Ta’if’in kuşatılması  Kuşatma başarısız            Ta’if
# 22           Bizans’a karşı       Savaş olmadı            Tabuk
#
#                      Savunanlar         Saldıranlar
# 0                             -         Müslümanlar
# 1                             -         Müslümanlar
# 2                             -         Müslümanlar
# 3                             -         Müslümanlar
# 4                   Müslümanlar              Kureyş
# 5                   Müslümanlar              Kureyş
# 6                   Müslümanlar        Banu Qaynuqa
# 7                             -         Müslümanlar
# 8                   Müslümanlar              Kureyş
# 9                             -         Müslümanlar
# 10                  Müslümanlar          Banu Nadir
# 11                            -         Müslümanlar
# 12                            -         Müslümanlar
# 13                            -         Müslümanlar
# 14                  Müslümanlar  Müttefik kuvvetler
# 15                  Müslümanlar        Banu Qurayza
# 16                  Müslümanlar         Banu Lahyan
# 17                            -         Müslümanlar
# 18       Bizans ve müttefikleri         Müslümanlar
# 19                       Kureyş         Müslümanlar
# 20  Ta’if ve Hawazin kabileleri         Müslümanlar
# 21             Ta’if kabileleri         Müslümanlar
# 22       Bizans ve müttefikleri         Müslümanlar

# %%
df_battle=df_battle.rename(columns={"kId": "bID"})

# %%
saldiri_sayilari = df_battle["Saldıranlar"].groupby(df_battle["Saldıranlar"]).size()

# Sonuçları yazdır
print(saldiri_sayilari)
# Out:
# Saldıranlar
# Banu Lahyan            1
# Banu Nadir             1
# Banu Qaynuqa           1
# Banu Qurayza           1
# Kureyş                 3
# Müslümanlar           15
# Müttefik kuvvetler     1
# Name: Saldıranlar, dtype: int64

# %%
saldiri_sayilari = df_battle["Sonuç"].groupby(df_battle["Sonuç"]).size()

# Sonuçları yazdır
print(saldiri_sayilari)
# Out:
# Sonuç
# Başarılı              5
# Büyük zafer           1
# Kayıp                 2
# Kuşatma başarısız     1
# Kuşatma ve sürgün     1
# Savaş olmadı         11
# Sürgün                2
# Name: Sonuç, dtype: int64

# %%
df_battle
# Out:
#       bID          Gazve Adı                        Tarih  \
# 0   27001  Waddan (al-Abwa’)            August 623 (1 AH)
# 1   27002              Buwat         September 623 (1 AH)
# 2   27003             Safwan         September 623 (1 AH)
# 3   27004    Zul Al-Ushairah          December 623 (1 AH)
# 4   27005        Nakhla Raid           January 624 (2 AH)
# 5   27006               Badr          13 March 624 (2 AH)
# 6   27007       Banu Qaynuqa             April 624 (2 AH)
# 7   27008              Sawiq          May/June 624 (2 AH)
# 8   27009               Uhud          23 March 625 (3 AH)
# 9   27010      Hamra al-Asad             March 625 (3 AH)
# 10  27011         Banu Nadir            August 625 (3 AH)
# 11  27012     Badr al-Maw’id             April 626 (4 AH)
# 12  27013       Dhat al-Riqa              June 626 (4 AH)
# 13  27014    Dumat al-Jandal  August/September 626 (4 AH)
# 14  27015             Trench             April 627 (5 AH)
# 15  27016       Banu Qurayza               May 627 (5 AH)
# 16  27017        Banu Lahyan              July 627 (5 AH)
# 17  27018          Dhu Qarad            August 627 (5 AH)
# 18  27019             Mu’tah         September 629 (7 AH)
# 19  27020  Conquest of Mecca           January 630 (7 AH)
# 20  27021             Hunayn              June 630 (8 AH)
# 21  27022        Ta’if Siege              June 630 (8 AH)
# 22  27023              Tabuk           October 630 (8 AH)
#
#                        Amaç              Sonuç              Yer  \
# 0   Yol keşfi ve ittifaklar       Savaş olmadı         Al-Abwa’
# 1            Kervan baskını       Savaş olmadı            Buwat
# 2             Düşman takibi       Savaş olmadı           Safwan
# 3            Kervan baskını       Savaş olmadı  Zul Al-Ushairah
# 4            Kervan baskını           Başarılı           Nakhla
# 5    Kervan baskını / Savaş        Büyük zafer             Badr
# 6            İttifak ihlali             Sürgün           Medine
# 7             Düşman takibi       Savaş olmadı                -
# 8                   Savunma              Kayıp             Uhud
# 9             Düşman takibi       Savaş olmadı    Hamra al-Asad
# 10           İttifak ihlali             Sürgün           Medine
# 11            Düşman takibi       Savaş olmadı             Badr
# 12            Düşman takibi       Savaş olmadı     Dhat al-Riqa
# 13           Siyasi kontrol           Başarılı  Dumat al-Jandal
# 14                  Savunma           Başarılı           Medine
# 15           İttifak ihlali  Kuşatma ve sürgün           Medine
# 16                  İntikam       Savaş olmadı                -
# 17            Düşman takibi       Savaş olmadı        Dhu Qarad
# 18           Bizans’a karşı              Kayıp           Mu’tah
# 19          Mekke’nin fethi           Başarılı            Mekke
# 20         Kabilelere karşı           Başarılı           Hunayn
# 21     Ta’if’in kuşatılması  Kuşatma başarısız            Ta’if
# 22           Bizans’a karşı       Savaş olmadı            Tabuk
#
#                      Savunanlar         Saldıranlar
# 0                             -         Müslümanlar
# 1                             -         Müslümanlar
# 2                             -         Müslümanlar
# 3                             -         Müslümanlar
# 4                   Müslümanlar              Kureyş
# 5                   Müslümanlar              Kureyş
# 6                   Müslümanlar        Banu Qaynuqa
# 7                             -         Müslümanlar
# 8                   Müslümanlar              Kureyş
# 9                             -         Müslümanlar
# 10                  Müslümanlar          Banu Nadir
# 11                            -         Müslümanlar
# 12                            -         Müslümanlar
# 13                            -         Müslümanlar
# 14                  Müslümanlar  Müttefik kuvvetler
# 15                  Müslümanlar        Banu Qurayza
# 16                  Müslümanlar         Banu Lahyan
# 17                            -         Müslümanlar
# 18       Bizans ve müttefikleri         Müslümanlar
# 19                       Kureyş         Müslümanlar
# 20  Ta’if ve Hawazin kabileleri         Müslümanlar
# 21             Ta’if kabileleri         Müslümanlar
# 22       Bizans ve müttefikleri         Müslümanlar

# %%
df_battle=df_battle.rename(columns={"Gazve Adı	": "adi"})

# %%
df_battle["Gazve Adı"] = df_battle["Gazve Adı"].str.upper()

# %%
df_battle.to_json("battle_eklenm")
# Out:
#       bID          Gazve Adı                        Tarih  \
# 0   27001  WADDAN (AL-ABWA’)            August 623 (1 AH)
# 1   27002              BUWAT         September 623 (1 AH)
# 2   27003             SAFWAN         September 623 (1 AH)
# 3   27004    ZUL AL-USHAIRAH          December 623 (1 AH)
# 4   27005        NAKHLA RAID           January 624 (2 AH)
# 5   27006               BADR          13 March 624 (2 AH)
# 6   27007       BANU QAYNUQA             April 624 (2 AH)
# 7   27008              SAWIQ          May/June 624 (2 AH)
# 8   27009               UHUD          23 March 625 (3 AH)
# 9   27010      HAMRA AL-ASAD             March 625 (3 AH)
# 10  27011         BANU NADIR            August 625 (3 AH)
# 11  27012     BADR AL-MAW’ID             April 626 (4 AH)
# 12  27013       DHAT AL-RIQA              June 626 (4 AH)
# 13  27014    DUMAT AL-JANDAL  August/September 626 (4 AH)
# 14  27015             TRENCH             April 627 (5 AH)
# 15  27016       BANU QURAYZA               May 627 (5 AH)
# 16  27017        BANU LAHYAN              July 627 (5 AH)
# 17  27018          DHU QARAD            August 627 (5 AH)
# 18  27019             MU’TAH         September 629 (7 AH)
# 19  27020  CONQUEST OF MECCA           January 630 (7 AH)
# 20  27021             HUNAYN              June 630 (8 AH)
# 21  27022        TA’IF SIEGE              June 630 (8 AH)
# 22  27023              TABUK           October 630 (8 AH)
#
#                        Amaç              Sonuç              Yer  \
# 0   Yol keşfi ve ittifaklar       Savaş olmadı         Al-Abwa’
# 1            Kervan baskını       Savaş olmadı            Buwat
# 2             Düşman takibi       Savaş olmadı           Safwan
# 3            Kervan baskını       Savaş olmadı  Zul Al-Ushairah
# 4            Kervan baskını           Başarılı           Nakhla
# 5    Kervan baskını / Savaş        Büyük zafer             Badr
# 6            İttifak ihlali             Sürgün           Medine
# 7             Düşman takibi       Savaş olmadı                -
# 8                   Savunma              Kayıp             Uhud
# 9             Düşman takibi       Savaş olmadı    Hamra al-Asad
# 10           İttifak ihlali             Sürgün           Medine
# 11            Düşman takibi       Savaş olmadı             Badr
# 12            Düşman takibi       Savaş olmadı     Dhat al-Riqa
# 13           Siyasi kontrol           Başarılı  Dumat al-Jandal
# 14                  Savunma           Başarılı           Medine
# 15           İttifak ihlali  Kuşatma ve sürgün           Medine
# 16                  İntikam       Savaş olmadı                -
# 17            Düşman takibi       Savaş olmadı        Dhu Qarad
# 18           Bizans’a karşı              Kayıp           Mu’tah
# 19          Mekke’nin fethi           Başarılı            Mekke
# 20         Kabilelere karşı           Başarılı           Hunayn
# 21     Ta’if’in kuşatılması  Kuşatma başarısız            Ta’if
# 22           Bizans’a karşı       Savaş olmadı            Tabuk
#
#                      Savunanlar         Saldıranlar
# 0                             -         Müslümanlar
# 1                             -         Müslümanlar
# 2                             -         Müslümanlar
# 3                             -         Müslümanlar
# 4                   Müslümanlar              Kureyş
# 5                   Müslümanlar              Kureyş
# 6                   Müslümanlar        Banu Qaynuqa
# 7                             -         Müslümanlar
# 8                   Müslümanlar              Kureyş
# 9                             -         Müslümanlar
# 10                  Müslümanlar          Banu Nadir
# 11                            -         Müslümanlar
# 12                            -         Müslümanlar
# 13                            -         Müslümanlar
# 14                  Müslümanlar  Müttefik kuvvetler
# 15                  Müslümanlar        Banu Qurayza
# 16                  Müslümanlar         Banu Lahyan
# 17                            -         Müslümanlar
# 18       Bizans ve müttefikleri         Müslümanlar
# 19                       Kureyş         Müslümanlar
# 20  Ta’if ve Hawazin kabileleri         Müslümanlar
# 21             Ta’if kabileleri         Müslümanlar
# 22       Bizans ve müttefikleri         Müslümanlar

# %%
for index, row in df_battle.iterrows():
        # Create Anne node
       run_query(f"""
           MERGE (b:Gazve {{bID: {row["bID"]}, adi: "{row["Gazve Adı"]}",tarih : "{row["Tarih"]}" , konum :"{ row["Yer"]}", Savunanlar :"{row["Savunanlar"]}",Saldiranlar:"{row["Saldıranlar"]}" ,Amac:"{row["Amaç"]}" ,Sonuc:"{row["Sonuç"]}"	}})
        """)
       # run_query(node_query, anne_id=int(row["bID"]), anne_adi=row["adi"], tarih=row["tarih"], konum=row["konum"] )

# %%
 run_query(f"""
            match (n:Gazve) return n
        """)
# Out:
#                                                     n
# 0   (Amac, tarih, Sonuc, konum, adi, bID, Saldiran...
# 1   (Amac, tarih, Sonuc, konum, adi, bID, Savunanl...
# 2   (Amac, tarih, Sonuc, konum, adi, bID, Saldiran...
# 3   (Amac, tarih, Sonuc, konum, adi, bID, Saldiran...
# 4   (Amac, tarih, Sonuc, konum, adi, bID, Saldiran...
# 5   (Amac, tarih, Sonuc, konum, adi, bID, Saldiran...
# 6   (Amac, tarih, Sonuc, konum, adi, bID, Saldiran...
# 7   (Amac, tarih, Sonuc, konum, adi, bID, Saldiran...
# 8   (Amac, tarih, Sonuc, konum, adi, bID, Savunanl...
# 9   (Amac, tarih, Sonuc, konum, adi, bID, Saldiran...
# 10  (Amac, tarih, Sonuc, konum, adi, bID, Saldiran...
# 11  (Amac, tarih, Sonuc, konum, adi, bID, Savunanl...
# 12  (Amac, tarih, Sonuc, konum, adi, bID, Saldiran...
# 13  (Amac, tarih, Sonuc, konum, adi, bID, Savunanl...
# 14  (Amac, tarih, Sonuc, konum, adi, bID, Saldiran...
# 15  (Amac, tarih, Sonuc, konum, adi, bID, Saldiran...
# 16  (Amac, tarih, Sonuc, konum, adi, bID, Saldiran...
# 17  (Amac, tarih, Sonuc, konum, adi, bID, Saldiran...
# 18  (Amac, tarih, Sonuc, konum, adi, bID, Savunanl...
# 19  (Amac, tarih, Sonuc, konum, adi, bID, Saldiran...
# 20  (Amac, tarih, Sonuc, konum, adi, bID, Saldiran...
# 21  (Amac, tarih, Sonuc, konum, adi, bID, Savunanl...
# 22  (Amac, tarih, Sonuc, konum, adi, bID, Savunanl...

# %%
 run_query(f"""
           MERGE (bolge:BOLGE {{bID:934001, adi: "Mekke", Konum: "21.4225° North, 39.8262° East"}})
            MERGE (bolge:BOLGE {{bID:934002, adi: "Madine", Konum: "24.4709° North, 39.6122° East"}})

        """)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 run_query(f"""
#       2           MERGE (bolge:BOLGE {{bID:934001, adi: "Mekke", Konum: "21.4225° North, 39.8262° East"}})
#       3            MERGE (bolge:BOLGE {{bID:934002, adi: "Madine", Konum: "24.4709° North, 39.6122° East"}})
#       4
#       5        """)
#
# NameError: name 'run_query' is not defined

# %%
bolge= "Madine"
run_query(f"""
match (n:Gazve) where n.konum Contains "{bolge}" 
   Merge (p:BOLGE {{bID:934002, adi: "Madine", Konum: "24.4709° North, 39.6122° East"}})

    with n, p
    Merge (n)-[:Happened_In]->(p) return p
""")
# Out:
#                    p
# 0  (Konum, adi, bID)

# %%
run_query("MATCH ()-[r:Happened_In]->() WHERE ID(r) > 1 DELETE r return count(r) ")
# Out:
#    count(r)
# 0         2

# %%
sahabe = pd.read_csv("C:/Users/Acer/.Neo4jDesktop/relate-data/dbmss/dbms-66f1e2f7-be36-4f2a-99f8-c7bc33af8512/import/p1.csv")

# %%
sahabe
# Out:
#                       adi                                              lakab  \
# 0     Ebu Bekir es-Sıddık  Abdullah b. Osman b. Amir b. Amr b. Ka'b b. Sa...
# 1  Hamza b. Abdilmuttalib                                          asadullah
#
#    pID                                  anne           baba  dogum_yili  \
# 0    1  Ümmü'l-Hayr Sülma bintu Suhr b. Amir     Ebû Kuhâfe         -50
# 1    2                      Hâle bint Vüheyb  Abdulmuttalib         -54
#
#    kabile                savas  Olum
# 0    teym  [huneyn,uhud,bedir]   NaN
# 1  Kureyş         [bedir,uhud]  uhud

# %%
kabileler = pd.read_json("C:/Users/Acer/.Neo4jDesktop/relate-data/dbmss/dbms-66f1e2f7-be36-4f2a-99f8-c7bc33af8512/import/kabile.json")

# %%
kabileler
# Out:
#       kId     adi  Bölge                                                Kök  \
# 0  145002  Kureyş  Mekke                                    [Fihr b. Mâlik]
# 1  145001    Teym  Mekke  Teym b. Mürre b. Kâ‘b b. Lüey b. Gâlib b. Fihr...
#
#                                             Liderler  \
# 0      [Abdülmüttalib, Ebû Tâlib, Abbas, Ebû Sûfyân]
# 1  [Abdullah b. Cüd‘ân, Osman b. Amr, Talha b. Ub...
#
#                                   Önemli Şahsiyetler
# 0  [Hz. Peygamber (Muhammed), Ebû Cehil, Velîd b....
# 1  [Hz. Ebû Bekir, Talha b. Ubeydullah, Abdullah ...

# %%
for index, row in kabileler.iterrows():
    run_query(f"""
    MERGE (k:Kabile {{kID:{row["kId"]}, adi: "{row["adi"]}", Kok:"{row["Kök"]}" , bolge :"{row["Bölge"]}" }})
    WITH k
    MATCH (n:BOLGE) WHERE n.adi CONTAINS "{row["Bölge"]}" 
    WITH n, k
    MERGE (k)-[:Belong_To]->(n) 
    RETURN n, k
    """)

# %%
run_query("""MATCH (n:BOLGE) WHERE n.adi CONTAINS "Mekke" return n.adi""")
# Out:
#    n.adi
# 0  Mekke
